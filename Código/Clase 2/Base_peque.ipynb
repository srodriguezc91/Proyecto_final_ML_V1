# %%
import pandas as pd

# %%
DF=pd.read_csv('Base Grande.csv')

for i in range(10):
    DF2=DF.iloc[1000*i:1000*(i+1)]
    DF2.to_csv('Bases_peque/Base_'+str(i)+'.csv')

# %%
import os 
dflist=[]
for i in sorted(os.listdir('Bases_peque')):    
    dflist.append(pd.read_csv('Bases_peque/'+i))
pd.concat(dflist,axis=0)
# Out:
#      Unnamed: 0  Customer_ID  custcare_Mean new_cell  \
# 0             0      1000014       0.000000        Y
# 1             1      1000016       1.000000        N
# 2             2      1000021       0.333333        U
# 3             3      1000023       0.000000        N
# 4             4      1000029       0.000000        N
# ..          ...          ...            ...      ...
# 992        9992      1099907      17.333333        U
# 993        9993      1099932       0.000000        U
# 994        9994      1099963       0.000000        U
# 995        9995      1099981       0.333333        U
# 996        9996      1099992       0.000000        Y
#
#                               area creditcd
# 0         CENTRAL-SOUTH TEXAS AREA        N
# 1                      DALLAS AREA        Y
# 2                   TENNESSEE AREA        Y
# 3    NORTHWEST-ROCKY MOUNTAIN AREA        N
# 4                 NEW ENGLAND AREA        Y
# ..                             ...      ...
# ...
